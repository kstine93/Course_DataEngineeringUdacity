# %% [markdown]
# ### Intro
# This is a Python notebook to explain and try out more advanced Python SQL interactions

# %%
#1. commands beginning with '%' are sent to the terminal (Cool!)
#2. ipython-sql allows you to specify sql commands in-line (not as strings) by using '%' or '%%' (see below)
# %pip install ipython-sql

# %%
#The percent operator allows you to load extensions to make the Python shell interpret commands differently.
#More info: https://ipython.readthedocs.io/en/stable/config/extensions/index.html
# %load_ext sql

# %%
# Note: port 5432 is the default used by postgres

db_host = '127.0.0.1'
db = 'pagila'
db_user = 'basic_user'
db_password = 'password'
db_port = '5432'

connection = f'postgresql://{db_user}:{db_password}@{db_host}:{db_port}/{db}'
print(connection)
# Out:
# postgresql://basic_user:password@127.0.0.1:5432/pagila

# %%
#Connecting to Database
# %sql $connection

# %%
'''
Notes on '%' operator when using sql commands:
1. Each command preceded by '%' will be interpreted by the terminal
2. You can use '$' to insert Python variables into these single-line commands
3. You can also write multi-line commands with '%%', but these do not support inserting Python variables with '$'
'''
# %sql SELECT * FROM store;
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 2 rows affected.
# [(1, 1, 1, datetime.datetime(2006, 2, 15, 9, 57, 12)),
#  (2, 2, 2, datetime.datetime(2006, 2, 15, 9, 57, 12))]

# %%
# Showing an overview of how much data we have:

#%sql SELECT * FROM information_schema.tables WHERE table_schema = 'public';
tables = ['film','store','customer','rental','payment','staff','city','country']
for tbl in tables:
    data = %sql SELECT COUNT(*) FROM $tbl;
    print(f'{tbl}\t' + str(data[0][0]))

# %%
#Get range of all payment dates:
# %%sql
SELECT min(payment_date) as start, max(payment_date) as end from payment;

# %% [markdown]
# #### See all districts where customers are living

# %%
# %%sql
# SELECT district, SUM(city_id) as count
# FROM address
# GROUP BY district
# ORDER BY count DESC
# LIMIT 20;

# %% [markdown]
# #### What are the top-grossing movies in this database?
# So what are the movies which, in aggregate, have earned the most money?

# %%
# %%sql
# SELECT SUM(payment.amount) as income, film.film_id, film.title
# FROM payment
# JOIN rental ON payment.rental_id = rental.rental_id
# JOIN inventory ON rental.inventory_id = inventory.inventory_id
# JOIN film ON inventory.film_id = film.film_id
# GROUP BY film.film_id, film.title
# ORDER BY income DESC
# LIMIT 20;

# %% [markdown]
# #### What are the cities whose customers provide the most income in this database?
# So what are the cities where customers live which, when aggregated, have paid the most?

# %%
# %%sql
# SELECT SUM(payment.amount) as income, city.city_id, city.city
# FROM payment
# JOIN rental ON payment.rental_id = rental.rental_id
# JOIN customer ON rental.customer_id = customer.customer_id
# JOIN address ON customer.address_id = address.address_id
# JOIN city on address.city_id = city.city_id
# GROUP BY city.city_id, city.city
# ORDER BY income DESC
# LIMIT 10;

# %% [markdown]
# #### Revenue of Movie by Customer City and by Month

# %%
# %%sql
# SELECT film.title,
#     SUM(payment.amount) AS income,
#     city.city,
#     EXTRACT(month FROM payment.payment_date) as month
# FROM payment
# JOIN rental ON payment.rental_id = rental.rental_id
# JOIN customer ON rental.customer_id = customer.customer_id
# JOIN address ON customer.address_id = address.address_id
# JOIN city on address.city_id = city.city_id
# JOIN inventory ON rental.inventory_id = inventory.inventory_id
# JOIN film ON inventory.film_id = film.film_id
# GROUP BY city.city, month, film.title
# ORDER BY month, income DESC
# LIMIT 10;

# %% [markdown]
# ### Changing Pagila to Fact + Dimension Tables
# In order to make the queries above easier to write (and to have them run faster) we will transform the Pagila database to be fact + dimension tables.
# The fact + dimension tables have already been designed (see image below), but let's talk about the logic behind this redesign.
#
# ![image](media/3nf_to_star.png)
#
# 1. The primary 'interaction' that we are interested in is **sales**. All of our queries are basically revolving around how to break down sales in different ways. Therefore, it makes sense for us to focus on 'sales' as our main fact table, and have dimension tables support the various ways we want to analyse these data further.
# 2. When it comes to the 'sales' fact table, we need to represent (a) relationships between sales and dimension tables and (b) any attributes of sales which don't make sense to store in a separate dimension table (i.e., sales amount).
#
# Let's get started on making this change from the 3NF form to the star schema.

# %% [markdown]
# ## Creating Star Schema
# #### DIMENSION - date table
# The date table doesn't actually exist in the 3NF table, but we can derive it quite easily

# %% [markdown]
# ##### Creating dimdate Table:

# %%
# %%sql
# CREATE TABLE dimdate (
#     date_key integer NOT NULL PRIMARY KEY,
#     date DATE NOT NULL,
#     year SMALLINT CHECK (year BETWEEN 1900 AND 3000) NOT NULL,
#     quarter SMALLINT CHECK (quarter BETWEEN 1 AND 4) NOT NULL,
#     month SMALLINT CHECK (month BETWEEN 1 AND 12) NOT NULL,
#     day SMALLINT CHECK (day BETWEEN 1 AND 31) NOT NULL,
#     week SMALLINT CHECK (week BETWEEN 1 AND 54) NOT NULL,
#     is_weekend BOOLEAN NOT NULL
# )

# %% [markdown]
# ##### Populating dimdate Table from 'Payment_Date'
# Notes: I guess the best way to pull data from 1 table and use it to populate another is to use Python.
#
# Plan:
# 1. Can I iterate over results of Postgres query, transform data as needed, and then INSERT into new table?
# 2. If I do this, I'm not sure it really makes sense to use %sql syntax - If I use psycopg2, I can query Postgres more programmatically and iterate over the results more easily.
#
# Update:
# It looks like there's actually a way to do this purely within Postgres queries! It's essentially wrapping a 'select' statement with an 'insert' statement See below...

# %%
# %%sql
# INSERT INTO dimdate (date_key, date, year, quarter, month, day, week, is_weekend)
# SELECT
#     DISTINCT(TO_CHAR(payment_date :: DATE, 'yyyyMMDD') ::INTEGER) as date_key,
#     DATE(payment_date) AS date,
#     EXTRACT(year FROM payment_date) AS year,
#     EXTRACT(quarter FROM payment_date) AS quarter,
#     EXTRACT(month FROM payment_date) AS month,
#     EXTRACT(day FROM payment_date) AS day,
#     EXTRACT(week FROM payment_date) AS week,
#     CASE WHEN EXTRACT(ISODOW FROM payment_date) IN (6,7) THEN true ELSE false END AS is_weekend
# FROM payment;

# %% [markdown]
# #### DIMENSION - customer table
# Note: Below I am creating some parameters for how 'email' must be defined. There is some debate on the interwebs as to how to best do this, but to keep things simple, I am only requiring:
# - the '@' character
# - a dot character to indicate at least 1 domain
# - some limits on the number of characters (See discussion here: https://stackoverflow.com/questions/386294/what-is-the-maximum-length-of-a-valid-email-address)

# %%
# %%sql
# CREATE EXTENSION citext;
# CREATE DOMAIN email AS citext
#     CHECK (value ~ '.{1,64}?@.*?\.org')
# Out:
# UsageError: Cell magic `%%sql` not found.

# %% [markdown]
# ##### Creating Customer Table:

# %%
# %%sql
# CREATE TABLE dimcustomer (
#     customer_key SERIAL NOT NULL PRIMARY KEY,
#     customer_id INTEGER NOT NULL,
#     first_name VARCHAR,
#     last_name VARCHAR,
#     email EMAIL UNIQUE NOT NULL,
#     address VARCHAR,
#     address2 VARCHAR,
#     district VARCHAR,
#     city VARCHAR,
#     country VARCHAR,
#     postal_code VARCHAR,
#     phone VARCHAR,
#     active BOOLEAN NOT NULL,
#     create_date DATE NOT NULL,
#     start_date DATE,
#     end_date DATE
# )

# %% [markdown]
# ##### Populating dimcustomer Table:

# %%
# %%sql
# INSERT INTO dimcustomer (customer_id, first_name, last_name, email, address, address2,
# district, city, country, postal_code, phone, active, create_date, start_date, end_date)
# SELECT
#     c.customer_id,
#     c.first_name,
#     c.last_name,
#     c.email,
#     a.address,
#     a.address2,
#     a.district,
#     city.city,
#     country.country,
#     a.postal_code,
#     a.phone,
#     CAST(c.active AS BOOLEAN),
#     c.create_date,
#     now() AS start_date,
#     now() AS end_date
# FROM customer c
# JOIN address a  ON (c.address_id = a.address_id)
# JOIN city       ON (a.city_id = city.city_id)
# JOIN country    ON (city.country_id = country.country_id);

# %% [markdown]
# #### DIMENSION - movie table

# %%
# %%sql
# CREATE TABLE dimmovie (
#     movie_key SERIAL NOT NULL PRIMARY KEY,
#     film_id INTEGER NOT NULL,
#     title VARCHAR NOT NULL,
#     description VARCHAR NOT NULL,
#     release_year SMALLINT CHECK (release_year BETWEEN 1000 AND 3000) NOT NULL,
#     language VARCHAR NOT NULL,
#     original_language VARCHAR,
#     rental_duration SMALLINT NOT NULL,
#     length REAL NOT NULL,
#     rating VARCHAR,
#     special_features VARCHAR NOT NULL
# )

# %% [markdown]
# ##### Populating dimcustomer Table:

# %%
# %%sql
# INSERT INTO dimmovie (film_id, title, description, release_year,
# language, original_language, rental_duration, length, rating, special_features)
# SELECT
#     f.film_id,
#     f.title,
#     f.description,
#     f.release_year,
#     l.name AS language,
#     orig_lang.name AS original_language,
#     f.rental_duration,
#     f.length,
#     f.rating,
#     f.special_features
# FROM film f
# JOIN language l         ON (f.language_id = l.language_id)
# LEFT JOIN language orig_lang ON (f.original_language_id = orig_lang.language_id);

# %% [markdown]
# #### DIMENSION - store table

# %%
# %%sql
# CREATE TABLE dimstore (
#     store_key SERIAL NOT NULL PRIMARY KEY,
#     store_id INTEGER NOT NULL,
#     address VARCHAR NOT NULL,
#     address2 VARCHAR,
#     district VARCHAR,
#     city VARCHAR NOT NULL,
#     country VARCHAR NOT NULL,
#     postal_code VARCHAR NOT NULL,
#     manager_first_name VARCHAR,
#     manager_last_name VARCHAR,
#     start_date DATE,
#     end_date DATE
# )

# %% [markdown]
# ##### Populating dimstore Table:

# %%
# %%sql
# INSERT INTO dimstore (store_id, address, address2, district, city, country, postal_code,
# manager_first_name, manager_last_name, start_date, end_date)
# SELECT
#     s.store_id,
#     a.address,
#     a.address2,
#     a.district,
#     c.city,
#     country.country,
#     a.postal_code,
#     staff.first_name AS manager_first_name,
#     staff.last_name AS manager_last_name,
#     now() AS start_date,
#     now() AS end_date
# FROM store s
# JOIN address a  ON (s.address_id = a.address_id)
# JOIN city c     ON (a.city_id = c.city_id)
# JOIN country    ON (c.country_id = country.country_id)
# JOIN staff      ON (s.manager_staff_id = staff.staff_id);

# %% [markdown]
# #### FACT - factsales table

# %%
# %%sql
# CREATE TABLE factsales (
#     sales_key       SERIAL PRIMARY KEY,
#     date_key        INT NOT NULL REFERENCES dimdate(date_key),
#     customer_key    INT NOT NULL REFERENCES dimcustomer(customer_key),
#     movie_key       INT NOT NULL REFERENCES dimmovie(movie_key),
#     store_key       INT NOT NULL REFERENCES dimstore(store_key),
#     sales_amount    DECIMAL(5,2) NOT NULL
# )
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# Done.
# []

# %% [markdown]
# ##### Populating factsales Table:

# %%
# %%sql
# INSERT INTO factsales (date_key, customer_key, movie_key, store_key, sales_amount)
# SELECT
#     TO_CHAR(p.payment_date :: DATE, 'yyyyMMDD')::INTEGER AS date_key,
#     p.customer_id AS customer_key,
#     i.film_id AS movie_key,
#     i.store_id AS store_key,
#     p.amount AS sales_amount
# FROM payment p
# JOIN rental r       ON (p.rental_id = r.rental_id)
# JOIN inventory i    ON (r.inventory_id = i.inventory_id);
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 32098 rows affected.
# []

# %% [markdown]
# ## Querying Data

# %%
# %%time
# %%sql
SELECT dimmovie.title, dimdate.month, dimcustomer.city, factsales.sales_amount FROM factsales
JOIN dimmovie ON factsales.movie_key = dimmovie.movie_key
JOIN dimcustomer ON factsales.customer_key = dimcustomer.customer_key
JOIN dimdate ON factsales.date_key = dimdate.date_key
LIMIT 10;
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 10 rows affected.
# CPU times: user 6.51 ms, sys: 1.62 ms, total: 8.13 ms
# Wall time: 7.44 ms
# [('SWARM GOLD', 1, 'Salinas', Decimal('1.99')),
#  ('PACKER MADIGAN', 1, 'Salinas', Decimal('0.99')),
#  ('SOMETHING DUCK', 1, 'Salinas', Decimal('6.99')),
#  ('DRACULA CRYSTAL', 1, 'Salinas', Decimal('0.99')),
#  ('CLONES PINOCCHIO', 1, 'Salinas', Decimal('4.99')),
#  ('DALMATIONS SWEDEN', 1, 'Salinas', Decimal('2.99')),
#  ('STRAIGHT HOURS', 1, 'Kalisz', Decimal('1.99')),
#  ('MARRIED GO', 1, 'Kalisz', Decimal('4.99')),
#  ('DIVORCE SHINING', 1, 'Kumbakonam', Decimal('8.99')),
#  ('GOLDMINE TYCOON', 1, 'Yantai', Decimal('0.99'))]

# %% [markdown]
# ## Speed Comparison: 3NF vs. Star Schema
# The start schema table query runs in 50-85 ms.
# The 3NF table query runs in 120 - 180 ms.
#
# This difference will only grow with the size of the tables; the conclusion being that de-normalizing data is a way to better scale analytics (at the cost of ACID and storage space).

# %%
# %%time
# %%sql
SELECT m.title, SUM(sales_amount) AS amount, c.city, d.month
FROM factsales
JOIN dimmovie m ON factsales.movie_key = m.movie_key
JOIN dimcustomer c ON factsales.customer_key = c.customer_key
JOIN dimdate d ON factsales.date_key = d.date_key
GROUP BY m.title, c.city, d.month
LIMIT 10;
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 10 rows affected.
# CPU times: user 5.9 ms, sys: 843 µs, total: 6.75 ms
# Wall time: 49.5 ms
# [('ACADEMY DINOSAUR', Decimal('3.98'), 'Almirante Brown', 3),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Celaya', 1),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Charlotte Amalie', 4),
#  ('ACADEMY DINOSAUR', Decimal('3.98'), 'Cianjur', 1),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Goinia', 3),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Hamilton', 4),
#  ('ACADEMY DINOSAUR', Decimal('3.98'), 'Jos Azueta', 4),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Kaliningrad', 3),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Kurashiki', 3),
#  ('ACADEMY DINOSAUR', Decimal('1.98'), 'Lipetsk', 4)]

# %%
# %%time
# %%sql
SELECT film.title, 
    SUM(payment.amount) AS income,
    city.city,
    EXTRACT(month FROM payment.payment_date) as month
FROM payment
JOIN rental ON payment.rental_id = rental.rental_id
JOIN customer ON rental.customer_id = customer.customer_id
JOIN address ON customer.address_id = address.address_id
JOIN city on address.city_id = city.city_id
JOIN inventory ON rental.inventory_id = inventory.inventory_id
JOIN film ON inventory.film_id = film.film_id
GROUP BY city.city, month, film.title
ORDER BY month, income DESC
LIMIT 10;
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 10 rows affected.
# CPU times: user 9.09 ms, sys: 1.63 ms, total: 10.7 ms
# Wall time: 177 ms
# [('SHOW LORD', Decimal('23.98'), 'Mannheim', Decimal('1')),
#  ('AMERICAN CIRCUS', Decimal('21.98'), 'Callao', Decimal('1')),
#  ('KISSING DOLLS', Decimal('21.98'), 'Toulon', Decimal('1')),
#  ('CASUALTIES ENCINO', Decimal('21.98'), 'Warren', Decimal('1')),
#  ('TELEGRAPH VOYAGE', Decimal('21.98'), 'Naala-Porto', Decimal('1')),
#  ('MOONSHINE CABIN', Decimal('19.98'), 'Balaiha', Decimal('1')),
#  ('MILLION ACE', Decimal('19.98'), 'Bergamo', Decimal('1')),
#  ('DARKO DORADO', Decimal('19.98'), 'Bhilwara', Decimal('1')),
#  ('MINE TITANS', Decimal('19.98'), 'Bradford', Decimal('1')),
#  ('AUTUMN CROW', Decimal('19.98'), 'Ashgabat', Decimal('1'))]

# %% [markdown]
# ## Creating OLAP Cubes
# - The results of the cube is a long table showing all possible combinations of dimensions specified in 'GROUP BY' clause and the output you specified (in this case, sum of sales)
# - 'Slicing' or 'Dicing' the cube is as easy as including 'WHERE' clauses in the query- so that only certain values of certain dimensions are included in the cube
# - 'Drilling Down' or 'Rolling up' require aggregating or disaggregating the data. This relationship (e.g., that 'day' belongs to 'month' belongs to 'year) is not explicitly specified, so I think we just need to re-do the query with using the aggregated or disaggregated attribute instead.
#
# Note:
# Let's say that you want to see results grouped by Month, Movie Rating, and City, but it's not actually important to you how 'Movie Rating' relates to 'Month' when 'City' is held constant. Instead of writing `GROUP BY (month, rating, city)` you could create **grouping sets** to more specifically say the cross-tabs that you want:
# `GROUP BY GROUPING SETS ((), month, rating, city,(rating, city))`
#
# Note: When you see "**None**" in results below, it actually means 'including all values in this attribute'

# %%
# %%time
# %%sql
SELECT SUM(sales_amount) AS amount, c.country, d.month, m.rating
FROM factsales
JOIN dimmovie m ON factsales.movie_key = m.movie_key
JOIN dimcustomer c ON factsales.customer_key = c.customer_key
JOIN dimdate d ON factsales.date_key = d.date_key
--GROUP BY GROUPING SETS ((), c.country, d.month,(c.country, m.rating))
ORDER BY c.country DESC, m.rating DESC;
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 1879 rows affected.
# CPU times: user 13 ms, sys: 200 µs, total: 13.2 ms
# Wall time: 98.4 ms
# [(Decimal('3.96'), 'Zambia', 2, 'R'),
#  (Decimal('51.92'), 'Zambia', 3, 'R'),
#  (Decimal('29.92'), 'Zambia', 4, 'R'),
#  (Decimal('9.98'), 'Zambia', 1, 'PG-13'),
#  (Decimal('11.98'), 'Zambia', 3, 'PG-13'),
#  (Decimal('7.98'), 'Zambia', 4, 'PG-13'),
#  (Decimal('13.98'), 'Zambia', 1, 'PG'),
#  (Decimal('11.96'), 'Zambia', 2, 'PG'),
#  (Decimal('21.94'), 'Zambia', 3, 'PG'),
#  (Decimal('17.94'), 'Zambia', 4, 'PG'),
#  (Decimal('1.98'), 'Zambia', 5, 'PG'),
#  (Decimal('9.98'), 'Zambia', 2, 'NC-17'),
#  (Decimal('29.94'), 'Zambia', 4, 'NC-17'),
#  (Decimal('1.98'), 'Zambia', 1, 'G'),
#  (Decimal('9.98'), 'Zambia', 2, 'G'),
#  (Decimal('9.98'), 'Zambia', 3, 'G'),
#  (Decimal('23.94'), 'Zambia', 4, 'G'),
#  (Decimal('11.96'), 'Yugoslavia', 2, 'R'),
#  (Decimal('39.90'), 'Yugoslavia', 3, 'R'),
#  (Decimal('79.86'), 'Yugoslavia', 4, 'R'),
#  (Decimal('31.92'), 'Yugoslavia', 1, 'PG-13'),
#  (Decimal('31.94'), 'Yugoslavia', 2, 'PG-13'),
#  (Decimal('37.92'), 'Yugoslavia', 3, 'PG-13'),
#  (Decimal('71.84'), 'Yugoslavia', 4, 'PG-13'),
#  (Decimal('1.98'), 'Yugoslavia', 2, 'PG'),
#  (Decimal('15.96'), 'Yugoslavia', 3, 'PG'),
#  (Decimal('55.88'), 'Yugoslavia', 4, 'PG'),
#  (Decimal('9.98'), 'Yugoslavia', 1, 'NC-17'),
#  (Decimal('35.92'), 'Yugoslavia', 3, 'NC-17'),
#  (Decimal('11.96'), 'Yugoslavia', 4, 'NC-17'),
#  (Decimal('9.98'), 'Yugoslavia', 1, 'G'),
#  (Decimal('15.96'), 'Yugoslavia', 2, 'G'),
#  (Decimal('17.98'), 'Yugoslavia', 3, 'G'),
#  (Decimal('37.92'), 'Yugoslavia', 4, 'G'),
#  (Decimal('15.96'), 'Yemen', 1, 'R'),
#  (Decimal('37.86'), 'Yemen', 2, 'R'),
#  (Decimal('45.88'), 'Yemen', 3, 'R'),
#  (Decimal('75.84'), 'Yemen', 4, 'R'),
#  (Decimal('1.98'), 'Yemen', 1, 'PG-13'),
#  (Decimal('39.92'), 'Yemen', 2, 'PG-13'),
#  (Decimal('55.86'), 'Yemen', 3, 'PG-13'),
#  (Decimal('111.74'), 'Yemen', 4, 'PG-13'),
#  (Decimal('5.98'), 'Yemen', 1, 'PG'),
#  (Decimal('35.94'), 'Yemen', 2, 'PG'),
#  (Decimal('101.82'), 'Yemen', 3, 'PG'),
#  (Decimal('113.82'), 'Yemen', 4, 'PG'),
#  (Decimal('7.96'), 'Yemen', 1, 'NC-17'),
#  (Decimal('5.98'), 'Yemen', 2, 'NC-17'),
#  (Decimal('61.84'), 'Yemen', 3, 'NC-17'),
#  (Decimal('143.66'), 'Yemen', 4, 'NC-17'),
#  (Decimal('21.94'), 'Yemen', 2, 'G'),
#  (Decimal('51.90'), 'Yemen', 3, 'G'),
#  (Decimal('79.80'), 'Yemen', 4, 'G'),
#  (Decimal('5.98'), 'Yemen', 5, 'G'),
#  (Decimal('9.96'), 'Virgin Islands, U.S.', 2, 'R'),
#  (Decimal('19.96'), 'Virgin Islands, U.S.', 3, 'R'),
#  (Decimal('15.96'), 'Virgin Islands, U.S.', 4, 'R'),
#  (Decimal('1.98'), 'Virgin Islands, U.S.', 2, 'PG-13'),
#  (Decimal('3.98'), 'Virgin Islands, U.S.', 3, 'PG-13'),
#  (Decimal('29.90'), 'Virgin Islands, U.S.', 4, 'PG-13'),
#  (Decimal('1.98'), 'Virgin Islands, U.S.', 1, 'PG'),
#  (Decimal('5.98'), 'Virgin Islands, U.S.', 3, 'PG'),
#  (Decimal('23.94'), 'Virgin Islands, U.S.', 4, 'PG'),
#  (Decimal('19.96'), 'Virgin Islands, U.S.', 2, 'NC-17'),
#  (Decimal('11.98'), 'Virgin Islands, U.S.', 3, 'NC-17'),
#  (Decimal('45.90'), 'Virgin Islands, U.S.', 4, 'NC-17'),
#  (Decimal('21.96'), 'Virgin Islands, U.S.', 2, 'G'),
#  (Decimal('9.98'), 'Virgin Islands, U.S.', 3, 'G'),
#  (Decimal('21.94'), 'Virgin Islands, U.S.', 4, 'G'),
#  (Decimal('15.96'), 'Vietnam', 1, 'R'),
#  (Decimal('45.88'), 'Vietnam', 2, 'R'),
#  (Decimal('83.82'), 'Vietnam', 3, 'R'),
#  (Decimal('45.86'), 'Vietnam', 4, 'R'),
#  (Decimal('5.98'), 'Vietnam', 5, 'R'),
#  (Decimal('17.94'), 'Vietnam', 1, 'PG-13'),
#  (Decimal('87.84'), 'Vietnam', 2, 'PG-13'),
#  (Decimal('157.72'), 'Vietnam', 3, 'PG-13'),
#  (Decimal('169.66'), 'Vietnam', 4, 'PG-13'),
#  (Decimal('11.96'), 'Vietnam', 5, 'PG-13'),
#  (Decimal('7.96'), 'Vietnam', 1, 'PG'),
#  (Decimal('33.92'), 'Vietnam', 2, 'PG'),
#  (Decimal('95.72'), 'Vietnam', 3, 'PG'),
#  (Decimal('147.68'), 'Vietnam', 4, 'PG'),
#  (Decimal('47.88'), 'Vietnam', 2, 'NC-17'),
#  (Decimal('151.62'), 'Vietnam', 3, 'NC-17'),
#  (Decimal('157.64'), 'Vietnam', 4, 'NC-17'),
#  (Decimal('25.96'), 'Vietnam', 1, 'G'),
#  (Decimal('17.96'), 'Vietnam', 2, 'G'),
#  (Decimal('67.82'), 'Vietnam', 3, 'G'),
#  (Decimal('95.78'), 'Vietnam', 4, 'G'),
#  (Decimal('13.94'), 'Venezuela', 1, 'R'),
#  (Decimal('91.78'), 'Venezuela', 2, 'R'),
#  (Decimal('115.70'), 'Venezuela', 3, 'R'),
#  (Decimal('133.72'), 'Venezuela', 4, 'R'),
#  (Decimal('9.98'), 'Venezuela', 2, 'PG-13'),
#  (Decimal('115.70'), 'Venezuela', 3, 'PG-13'),
#  (Decimal('109.76'), 'Venezuela', 4, 'PG-13'),
#  (Decimal('19.94'), 'Venezuela', 1, 'PG'),
#  (Decimal('81.84'), 'Venezuela', 2, 'PG'),
#  (Decimal('45.86'), 'Venezuela', 3, 'PG'),
#  (Decimal('89.70'), 'Venezuela', 4, 'PG'),
#  (Decimal('5.98'), 'Venezuela', 1, 'NC-17'),
#  (Decimal('27.92'), 'Venezuela', 2, 'NC-17'),
#  (Decimal('73.82'), 'Venezuela', 3, 'NC-17'),
#  (Decimal('141.66'), 'Venezuela', 4, 'NC-17'),
#  (Decimal('5.98'), 'Venezuela', 5, 'NC-17'),
#  (Decimal('9.98'), 'Venezuela', 1, 'G'),
#  (Decimal('69.84'), 'Venezuela', 2, 'G'),
#  (Decimal('87.82'), 'Venezuela', 3, 'G'),
#  (Decimal('109.70'), 'Venezuela', 4, 'G'),
#  (Decimal('5.98'), 'Venezuela', 5, 'G'),
#  (Decimal('81.80'), 'United States', 1, 'R'),
#  (Decimal('231.36'), 'United States', 2, 'R'),
#  (Decimal('566.64'), 'United States', 3, 'R'),
#  (Decimal('710.34'), 'United States', 4, 'R'),
#  (Decimal('119.68'), 'United States', 1, 'PG-13'),
#  (Decimal('267.36'), 'United States', 2, 'PG-13'),
#  (Decimal('596.60'), 'United States', 3, 'PG-13'),
#  (Decimal('754.24'), 'United States', 4, 'PG-13'),
#  (Decimal('27.92'), 'United States', 5, 'PG-13'),
#  (Decimal('93.78'), 'United States', 1, 'PG'),
#  (Decimal('245.32'), 'United States', 2, 'PG'),
#  (Decimal('622.60'), 'United States', 3, 'PG'),
#  (Decimal('574.72'), 'United States', 4, 'PG'),
#  (Decimal('9.94'), 'United States', 5, 'PG'),
#  (Decimal('187.64'), 'United States', 1, 'NC-17'),
#  (Decimal('211.44'), 'United States', 2, 'NC-17'),
#  (Decimal('792.14'), 'United States', 3, 'NC-17'),
#  (Decimal('700.30'), 'United States', 4, 'NC-17'),
#  (Decimal('13.94'), 'United States', 5, 'NC-17'),
#  (Decimal('135.70'), 'United States', 1, 'G'),
#  (Decimal('225.48'), 'United States', 2, 'G'),
#  (Decimal('460.92'), 'United States', 3, 'G'),
#  (Decimal('584.80'), 'United States', 4, 'G'),
#  (Decimal('5.98'), 'United States', 5, 'G'),
#  (Decimal('9.96'), 'United Kingdom', 1, 'R'),
#  (Decimal('101.78'), 'United Kingdom', 2, 'R'),
#  (Decimal('131.60'), 'United Kingdom', 3, 'R'),
#  (Decimal('175.64'), 'United Kingdom', 4, 'R'),
#  (Decimal('55.92'), 'United Kingdom', 1, 'PG-13'),
#  (Decimal('81.88'), 'United Kingdom', 2, 'PG-13'),
#  (Decimal('137.62'), 'United Kingdom', 3, 'PG-13'),
#  (Decimal('115.66'), 'United Kingdom', 4, 'PG-13'),
#  (Decimal('11.96'), 'United Kingdom', 5, 'PG-13'),
#  (Decimal('13.94'), 'United Kingdom', 1, 'PG'),
#  (Decimal('67.90'), 'United Kingdom', 2, 'PG'),
#  (Decimal('79.80'), 'United Kingdom', 3, 'PG'),
#  (Decimal('125.64'), 'United Kingdom', 4, 'PG'),
#  (Decimal('9.98'), 'United Kingdom', 5, 'PG'),
#  (Decimal('45.92'), 'United Kingdom', 1, 'NC-17'),
#  (Decimal('61.84'), 'United Kingdom', 2, 'NC-17'),
#  (Decimal('133.72'), 'United Kingdom', 3, 'NC-17'),
#  (Decimal('175.60'), 'United Kingdom', 4, 'NC-17'),
#  (Decimal('1.98'), 'United Kingdom', 5, 'NC-17'),
#  (Decimal('21.94'), 'United Kingdom', 1, 'G'),
#  (Decimal('51.84'), 'United Kingdom', 2, 'G'),
#  (Decimal('69.82'), 'United Kingdom', 3, 'G'),
#  (Decimal('167.66'), 'United Kingdom', 4, 'G'),
#  (Decimal('19.94'), 'United Arab Emirates', 1, 'R'),
#  (Decimal('23.92'), 'United Arab Emirates', 2, 'R'),
#  (Decimal('51.90'), 'United Arab Emirates', 3, 'R'),
#  (Decimal('79.84'), 'United Arab Emirates', 4, 'R'),
#  (Decimal('1.98'), 'United Arab Emirates', 1, 'PG-13'),
#  (Decimal('21.94'), 'United Arab Emirates', 2, 'PG-13'),
#  (Decimal('35.90'), 'United Arab Emirates', 3, 'PG-13'),
#  (Decimal('43.88'), 'United Arab Emirates', 4, 'PG-13'),
#  (Decimal('9.98'), 'United Arab Emirates', 5, 'PG-13'),
#  (Decimal('49.90'), 'United Arab Emirates', 2, 'PG'),
#  (Decimal('17.90'), 'United Arab Emirates', 3, 'PG'),
#  (Decimal('89.78'), 'United Arab Emirates', 4, 'PG'),
#  (Decimal('3.98'), 'United Arab Emirates', 1, 'NC-17'),
#  (Decimal('31.90'), 'United Arab Emirates', 2, 'NC-17'),
#  (Decimal('31.92'), 'United Arab Emirates', 3, 'NC-17'),
#  (Decimal('69.84'), 'United Arab Emirates', 4, 'NC-17'),
#  (Decimal('41.92'), 'United Arab Emirates', 3, 'G'),
#  (Decimal('39.90'), 'United Arab Emirates', 4, 'G'),
#  (Decimal('27.94'), 'Ukraine', 1, 'R'),
#  (Decimal('69.84'), 'Ukraine', 2, 'R'),
#  (Decimal('133.76'), 'Ukraine', 3, 'R'),
#  (Decimal('105.76'), 'Ukraine', 4, 'R'),
#  (Decimal('9.98'), 'Ukraine', 1, 'PG-13'),
#  (Decimal('21.94'), 'Ukraine', 2, 'PG-13'),
#  (Decimal('91.78'), 'Ukraine', 3, 'PG-13'),
#  (Decimal('103.74'), 'Ukraine', 4, 'PG-13'),
#  (Decimal('5.98'), 'Ukraine', 1, 'PG'),
#  (Decimal('35.92'), 'Ukraine', 2, 'PG'),
#  (Decimal('53.82'), 'Ukraine', 3, 'PG'),
#  (Decimal('97.84'), 'Ukraine', 4, 'PG'),
#  (Decimal('65.88'), 'Ukraine', 1, 'NC-17'),
#  (Decimal('9.98'), 'Ukraine', 2, 'NC-17'),
#  (Decimal('121.72'), 'Ukraine', 3, 'NC-17'),
#  (Decimal('193.58'), 'Ukraine', 4, 'NC-17'),
#  (Decimal('21.92'), 'Ukraine', 2, 'G'),
#  (Decimal('93.80'), 'Ukraine', 3, 'G'),
#  (Decimal('195.66'), 'Ukraine', 4, 'G'),
#  (Decimal('13.98'), 'Tuvalu', 1, 'R'),
#  (Decimal('13.98'), 'Tuvalu', 3, 'R'),
#  (Decimal('15.98'), 'Tuvalu', 1, 'PG-13'),
#  (Decimal('7.98'), 'Tuvalu', 2, 'PG-13'),
#  (Decimal('5.98'), 'Tuvalu', 3, 'PG-13'),
#  (Decimal('33.92'), 'Tuvalu', 4, 'PG-13'),
#  (Decimal('15.96'), 'Tuvalu', 3, 'PG'),
#  (Decimal('35.94'), 'Tuvalu', 4, 'PG'),
#  (Decimal('23.96'), 'Tuvalu', 1, 'NC-17'),
#  (Decimal('15.96'), 'Tuvalu', 2, 'NC-17'),
#  (Decimal('27.92'), 'Tuvalu', 3, 'NC-17'),
#  (Decimal('17.96'), 'Tuvalu', 4, 'NC-17'),
#  (Decimal('1.98'), 'Tuvalu', 3, 'G'),
#  (Decimal('9.98'), 'Tuvalu', 4, 'G'),
#  (Decimal('23.96'), 'Turkmenistan', 3, 'R'),
#  (Decimal('23.94'), 'Turkmenistan', 4, 'R'),
#  (Decimal('19.98'), 'Turkmenistan', 1, 'PG-13'),
#  (Decimal('19.96'), 'Turkmenistan', 2, 'PG-13'),
#  (Decimal('17.98'), 'Turkmenistan', 3, 'PG-13'),
#  (Decimal('7.96'), 'Turkmenistan', 4, 'PG-13'),
#  (Decimal('17.96'), 'Turkmenistan', 2, 'PG'),
#  (Decimal('25.96'), 'Turkmenistan', 3, 'PG'),
#  (Decimal('23.96'), 'Turkmenistan', 4, 'PG'),
#  (Decimal('5.98'), 'Turkmenistan', 5, 'PG'),
#  (Decimal('9.98'), 'Turkmenistan', 2, 'NC-17'),
#  (Decimal('17.96'), 'Turkmenistan', 3, 'NC-17'),
#  (Decimal('11.96'), 'Turkmenistan', 4, 'NC-17'),
#  (Decimal('15.96'), 'Turkmenistan', 2, 'G'),
#  (Decimal('21.98'), 'Turkmenistan', 3, 'G'),
#  (Decimal('7.98'), 'Turkmenistan', 4, 'G'),
#  (Decimal('73.86'), 'Turkey', 1, 'R'),
#  (Decimal('55.78'), 'Turkey', 2, 'R'),
#  (Decimal('197.52'), 'Turkey', 3, 'R'),
#  (Decimal('269.38'), 'Turkey', 4, 'R'),
#  (Decimal('47.88'), 'Turkey', 1, 'PG-13'),
#  (Decimal('93.76'), 'Turkey', 2, 'PG-13'),
#  (Decimal('283.34'), 'Turkey', 3, 'PG-13'),
#  (Decimal('337.22'), 'Turkey', 4, 'PG-13'),
#  (Decimal('5.98'), 'Turkey', 5, 'PG-13'),
#  (Decimal('25.94'), 'Turkey', 1, 'PG'),
#  (Decimal('79.82'), 'Turkey', 2, 'PG'),
#  (Decimal('225.50'), 'Turkey', 3, 'PG'),
#  (Decimal('285.24'), 'Turkey', 4, 'PG'),
#  (Decimal('41.90'), 'Turkey', 1, 'NC-17'),
#  (Decimal('85.78'), 'Turkey', 2, 'NC-17'),
#  (Decimal('189.58'), 'Turkey', 3, 'NC-17'),
#  (Decimal('297.26'), 'Turkey', 4, 'NC-17'),
#  (Decimal('51.88'), 'Turkey', 1, 'G'),
#  (Decimal('97.82'), 'Turkey', 2, 'G'),
#  (Decimal('267.40'), 'Turkey', 3, 'G'),
#  (Decimal('295.44'), 'Turkey', 4, 'G'),
#  (Decimal('15.96'), 'Turkey', 5, 'G'),
#  (Decimal('3.96'), 'Tunisia', 3, 'R'),
#  (Decimal('21.92'), 'Tunisia', 4, 'R'),
#  (Decimal('5.98'), 'Tunisia', 3, 'PG-13'),
#  (Decimal('11.96'), 'Tunisia', 4, 'PG-13'),
#  (Decimal('9.98'), 'Tunisia', 3, 'PG'),
#  (Decimal('23.94'), 'Tunisia', 4, 'PG'),
#  (Decimal('9.98'), 'Tunisia', 2, 'NC-17'),
#  (Decimal('9.98'), 'Tunisia', 3, 'NC-17'),
#  (Decimal('11.96'), 'Tunisia', 4, 'NC-17'),
#  (Decimal('3.98'), 'Tunisia', 3, 'G'),
#  (Decimal('41.92'), 'Tunisia', 4, 'G'),
#  (Decimal('1.98'), 'Tunisia', 5, 'G'),
#  (Decimal('13.96'), 'Tonga', 3, 'R'),
#  (Decimal('11.98'), 'Tonga', 1, 'PG-13'),
#  (Decimal('9.96'), 'Tonga', 2, 'PG-13'),
#  (Decimal('11.96'), 'Tonga', 3, 'PG-13'),
#  (Decimal('7.98'), 'Tonga', 4, 'PG-13'),
#  (Decimal('1.98'), 'Tonga', 3, 'PG'),
#  (Decimal('37.92'), 'Tonga', 4, 'PG'),
#  (Decimal('9.98'), 'Tonga', 2, 'NC-17'),
#  (Decimal('11.98'), 'Tonga', 4, 'NC-17'),
#  (Decimal('5.98'), 'Tonga', 1, 'G'),
#  (Decimal('23.96'), 'Tonga', 3, 'G'),
#  (Decimal('19.96'), 'Thailand', 2, 'R'),
#  (Decimal('47.90'), 'Thailand', 3, 'R'),
#  (Decimal('33.90'), 'Thailand', 4, 'R'),
#  (Decimal('15.96'), 'Thailand', 2, 'PG-13'),
#  (Decimal('57.86'), 'Thailand', 3, 'PG-13'),
#  (Decimal('53.86'), 'Thailand', 4, 'PG-13'),
#  (Decimal('0.00'), 'Thailand', 5, 'PG-13'),
#  (Decimal('9.98'), 'Thailand', 1, 'PG'),
#  (Decimal('27.92'), 'Thailand', 2, 'PG'),
#  (Decimal('65.84'), 'Thailand', 3, 'PG'),
#  (Decimal('105.80'), 'Thailand', 4, 'PG'),
#  (Decimal('9.98'), 'Thailand', 1, 'NC-17'),
#  (Decimal('27.94'), 'Thailand', 2, 'NC-17'),
#  (Decimal('55.88'), 'Thailand', 3, 'NC-17'),
#  (Decimal('117.74'), 'Thailand', 4, 'NC-17'),
#  (Decimal('15.96'), 'Thailand', 1, 'G'),
#  (Decimal('35.90'), 'Thailand', 2, 'G'),
#  (Decimal('67.88'), 'Thailand', 3, 'G'),
#  (Decimal('55.86'), 'Thailand', 4, 'G'),
#  (Decimal('11.96'), 'Thailand', 5, 'G'),
#  (Decimal('1.98'), 'Tanzania', 1, 'R'),
#  (Decimal('9.98'), 'Tanzania', 2, 'R'),
#  (Decimal('75.78'), 'Tanzania', 3, 'R'),
#  (Decimal('53.88'), 'Tanzania', 4, 'R'),
#  (Decimal('9.98'), 'Tanzania', 2, 'PG-13'),
#  (Decimal('37.92'), 'Tanzania', 3, 'PG-13'),
#  (Decimal('83.88'), 'Tanzania', 4, 'PG-13'),
#  (Decimal('5.98'), 'Tanzania', 1, 'PG'),
#  (Decimal('15.94'), 'Tanzania', 2, 'PG'),
#  (Decimal('29.90'), 'Tanzania', 3, 'PG'),
#  (Decimal('51.84'), 'Tanzania', 4, 'PG'),
#  (Decimal('19.96'), 'Tanzania', 1, 'NC-17'),
#  (Decimal('17.94'), 'Tanzania', 2, 'NC-17'),
#  (Decimal('71.82'), 'Tanzania', 3, 'NC-17'),
#  (Decimal('35.92'), 'Tanzania', 4, 'NC-17'),
#  (Decimal('9.98'), 'Tanzania', 1, 'G'),
#  (Decimal('15.96'), 'Tanzania', 2, 'G'),
#  (Decimal('57.88'), 'Tanzania', 3, 'G'),
#  (Decimal('65.84'), 'Tanzania', 4, 'G'),
#  (Decimal('9.98'), 'Tanzania', 5, 'G'),
#  (Decimal('65.86'), 'Taiwan', 2, 'R'),
#  (Decimal('191.50'), 'Taiwan', 3, 'R'),
#  (Decimal('281.24'), 'Taiwan', 4, 'R'),
#  (Decimal('11.96'), 'Taiwan', 5, 'R'),
#  (Decimal('49.90'), 'Taiwan', 1, 'PG-13'),
#  (Decimal('57.88'), 'Taiwan', 2, 'PG-13'),
#  (Decimal('191.50'), 'Taiwan', 3, 'PG-13'),
#  (Decimal('275.40'), 'Taiwan', 4, 'PG-13'),
#  (Decimal('5.98'), 'Taiwan', 5, 'PG-13'),
#  (Decimal('25.90'), 'Taiwan', 1, 'PG'),
#  (Decimal('19.88'), 'Taiwan', 2, 'PG'),
#  (Decimal('121.64'), 'Taiwan', 3, 'PG'),
#  (Decimal('241.50'), 'Taiwan', 4, 'PG'),
#  (Decimal('1.98'), 'Taiwan', 5, 'PG'),
#  (Decimal('33.90'), 'Taiwan', 1, 'NC-17'),
#  (Decimal('143.70'), 'Taiwan', 2, 'NC-17'),
#  (Decimal('185.48'), 'Taiwan', 3, 'NC-17'),
#  (Decimal('157.54'), 'Taiwan', 4, 'NC-17'),
#  (Decimal('1.98'), 'Taiwan', 1, 'G'),
#  (Decimal('55.88'), 'Taiwan', 2, 'G'),
#  (Decimal('107.76'), 'Taiwan', 3, 'G'),
#  (Decimal('175.58'), 'Taiwan', 4, 'G'),
#  (Decimal('17.94'), 'Taiwan', 5, 'G'),
#  (Decimal('29.90'), 'Switzerland', 3, 'R'),
#  (Decimal('43.88'), 'Switzerland', 4, 'R'),
#  (Decimal('0.00'), 'Switzerland', 5, 'R'),
#  (Decimal('25.96'), 'Switzerland', 2, 'PG-13'),
#  (Decimal('55.90'), 'Switzerland', 3, 'PG-13'),
#  (Decimal('109.76'), 'Switzerland', 4, 'PG-13'),
#  (Decimal('1.98'), 'Switzerland', 1, 'PG'),
#  (Decimal('9.96'), 'Switzerland', 2, 'PG'),
#  (Decimal('23.92'), 'Switzerland', 3, 'PG'),
#  (Decimal('43.92'), 'Switzerland', 4, 'PG'),
#  (Decimal('5.98'), 'Switzerland', 1, 'NC-17'),
#  (Decimal('15.98'), 'Switzerland', 2, 'NC-17'),
#  (Decimal('15.98'), 'Switzerland', 3, 'NC-17'),
#  (Decimal('27.94'), 'Switzerland', 4, 'NC-17'),
#  (Decimal('9.98'), 'Switzerland', 2, 'G'),
#  (Decimal('11.92'), 'Switzerland', 3, 'G'),
#  (Decimal('55.86'), 'Switzerland', 4, 'G'),
#  (Decimal('15.96'), 'Switzerland', 5, 'G'),
#  (Decimal('23.96'), 'Sweden', 2, 'R'),
#  (Decimal('5.94'), 'Sweden', 3, 'R'),
#  (Decimal('37.92'), 'Sweden', 4, 'R'),
#  (Decimal('9.98'), 'Sweden', 1, 'PG-13'),
#  (Decimal('23.94'), 'Sweden', 2, 'PG-13'),
#  (Decimal('45.92'), 'Sweden', 3, 'PG-13'),
#  (Decimal('25.94'), 'Sweden', 4, 'PG-13'),
#  (Decimal('33.90'), 'Sweden', 3, 'PG'),
#  (Decimal('13.96'), 'Sweden', 4, 'PG'),
#  (Decimal('11.96'), 'Sweden', 2, 'NC-17'),
#  (Decimal('11.98'), 'Sweden', 3, 'NC-17'),
#  (Decimal('31.94'), 'Sweden', 4, 'NC-17'),
#  (Decimal('11.98'), 'Sweden', 4, 'G'),
#  (Decimal('9.98'), 'Sudan', 1, 'R'),
#  (Decimal('25.90'), 'Sudan', 2, 'R'),
#  (Decimal('19.96'), 'Sudan', 3, 'R'),
#  (Decimal('25.90'), 'Sudan', 4, 'R'),
#  (Decimal('19.96'), 'Sudan', 1, 'PG-13'),
#  (Decimal('9.98'), 'Sudan', 2, 'PG-13'),
#  (Decimal('67.86'), 'Sudan', 3, 'PG-13'),
#  (Decimal('17.94'), 'Sudan', 4, 'PG-13'),
#  (Decimal('13.94'), 'Sudan', 2, 'PG'),
#  (Decimal('27.94'), 'Sudan', 3, 'PG'),
#  (Decimal('43.90'), 'Sudan', 4, 'PG'),
#  (Decimal('19.96'), 'Sudan', 1, 'NC-17'),
#  (Decimal('5.98'), 'Sudan', 2, 'NC-17'),
#  (Decimal('11.96'), 'Sudan', 3, 'NC-17'),
#  (Decimal('53.88'), 'Sudan', 4, 'NC-17'),
#  (Decimal('9.98'), 'Sudan', 3, 'G'),
#  (Decimal('69.90'), 'Sudan', 4, 'G'),
#  (Decimal('5.98'), 'Sri Lanka', 2, 'R'),
#  (Decimal('39.92'), 'Sri Lanka', 3, 'R'),
#  (Decimal('31.90'), 'Sri Lanka', 4, 'R'),
#  (Decimal('11.98'), 'Sri Lanka', 1, 'PG-13'),
#  (Decimal('15.94'), 'Sri Lanka', 3, 'PG-13'),
#  (Decimal('7.96'), 'Sri Lanka', 3, 'PG'),
#  (Decimal('11.96'), 'Sri Lanka', 4, 'PG'),
#  (Decimal('23.96'), 'Sri Lanka', 3, 'NC-17'),
#  (Decimal('9.98'), 'Sri Lanka', 4, 'NC-17'),
#  (Decimal('13.96'), 'Sri Lanka', 1, 'G'),
#  (Decimal('15.96'), 'Sri Lanka', 2, 'G'),
#  (Decimal('5.98'), 'Sri Lanka', 3, 'G'),
#  (Decimal('37.92'), 'Sri Lanka', 4, 'G'),
#  (Decimal('37.92'), 'Spain', 1, 'R'),
#  (Decimal('47.90'), 'Spain', 2, 'R'),
#  (Decimal('137.70'), 'Spain', 3, 'R'),
#  (Decimal('121.72'), 'Spain', 4, 'R'),
#  (Decimal('9.98'), 'Spain', 1, 'PG-13'),
#  (Decimal('57.88'), 'Spain', 2, 'PG-13'),
#  (Decimal('83.78'), 'Spain', 3, 'PG-13'),
#  (Decimal('59.82'), 'Spain', 4, 'PG-13'),
#  (Decimal('37.88'), 'Spain', 1, 'PG'),
#  (Decimal('121.78'), 'Spain', 3, 'PG'),
#  (Decimal('125.72'), 'Spain', 4, 'PG'),
#  (Decimal('19.96'), 'Spain', 5, 'PG'),
#  (Decimal('7.96'), 'Spain', 1, 'NC-17'),
#  (Decimal('17.96'), 'Spain', 2, 'NC-17'),
#  (Decimal('45.84'), 'Spain', 3, 'NC-17'),
#  (Decimal('129.74'), 'Spain', 4, 'NC-17'),
#  (Decimal('19.96'), 'Spain', 1, 'G'),
#  (Decimal('13.96'), 'Spain', 2, 'G'),
#  (Decimal('37.88'), 'Spain', 3, 'G'),
#  (Decimal('77.82'), 'Spain', 4, 'G'),
#  (Decimal('15.96'), 'South Korea', 1, 'R'),
#  (Decimal('17.94'), 'South Korea', 2, 'R'),
#  (Decimal('29.94'), 'South Korea', 3, 'R'),
#  (Decimal('93.74'), 'South Korea', 4, 'R'),
#  (Decimal('1.98'), 'South Korea', 5, 'R'),
#  (Decimal('11.96'), 'South Korea', 1, 'PG-13'),
#  (Decimal('13.94'), 'South Korea', 2, 'PG-13'),
#  (Decimal('119.80'), 'South Korea', 3, 'PG-13'),
#  (Decimal('113.72'), 'South Korea', 4, 'PG-13'),
#  (Decimal('5.98'), 'South Korea', 5, 'PG-13'),
#  (Decimal('17.96'), 'South Korea', 1, 'PG'),
#  (Decimal('53.88'), 'South Korea', 2, 'PG'),
#  (Decimal('91.86'), 'South Korea', 3, 'PG'),
#  (Decimal('151.68'), 'South Korea', 4, 'PG'),
#  (Decimal('17.94'), 'South Korea', 1, 'NC-17'),
#  (Decimal('9.98'), 'South Korea', 2, 'NC-17'),
#  (Decimal('81.82'), 'South Korea', 3, 'NC-17'),
#  (Decimal('151.64'), 'South Korea', 4, 'NC-17'),
#  (Decimal('29.94'), 'South Korea', 1, 'G'),
#  (Decimal('13.94'), 'South Korea', 2, 'G'),
#  (Decimal('31.86'), 'South Korea', 3, 'G'),
#  (Decimal('71.84'), 'South Korea', 4, 'G'),
#  (Decimal('45.90'), 'South Africa', 1, 'R'),
#  (Decimal('93.78'), 'South Africa', 2, 'R'),
#  (Decimal('185.58'), 'South Africa', 3, 'R'),
#  (Decimal('209.40'), 'South Africa', 4, 'R'),
#  (Decimal('65.84'), 'South Africa', 1, 'PG-13'),
#  (Decimal('75.82'), 'South Africa', 2, 'PG-13'),
#  (Decimal('245.52'), 'South Africa', 3, 'PG-13'),
#  (Decimal('149.66'), 'South Africa', 4, 'PG-13'),
#  (Decimal('59.90'), 'South Africa', 1, 'PG'),
#  (Decimal('17.94'), 'South Africa', 2, 'PG'),
#  (Decimal('159.58'), 'South Africa', 3, 'PG'),
#  (Decimal('175.58'), 'South Africa', 4, 'PG'),
#  (Decimal('9.98'), 'South Africa', 5, 'PG'),
#  (Decimal('15.92'), 'South Africa', 1, 'NC-17'),
#  (Decimal('85.80'), 'South Africa', 2, 'NC-17'),
#  (Decimal('183.60'), 'South Africa', 3, 'NC-17'),
#  (Decimal('209.52'), 'South Africa', 4, 'NC-17'),
#  (Decimal('11.96'), 'South Africa', 1, 'G'),
#  (Decimal('81.82'), 'South Africa', 2, 'G'),
#  (Decimal('133.68'), 'South Africa', 3, 'G'),
#  (Decimal('191.52'), 'South Africa', 4, 'G'),
#  (Decimal('17.94'), 'Slovakia', 1, 'R'),
#  (Decimal('5.98'), 'Slovakia', 3, 'R'),
#  (Decimal('39.90'), 'Slovakia', 4, 'R'),
#  (Decimal('15.96'), 'Slovakia', 2, 'PG-13'),
#  (Decimal('1.98'), 'Slovakia', 3, 'PG-13'),
#  (Decimal('25.94'), 'Slovakia', 4, 'PG-13'),
#  (Decimal('13.98'), 'Slovakia', 2, 'PG'),
#  (Decimal('5.98'), 'Slovakia', 3, 'PG'),
#  (Decimal('7.96'), 'Slovakia', 4, 'PG'),
#  (Decimal('3.98'), 'Slovakia', 2, 'NC-17'),
#  (Decimal('5.98'), 'Slovakia', 3, 'NC-17'),
#  (Decimal('21.94'), 'Slovakia', 3, 'G'),
#  (Decimal('11.96'), 'Slovakia', 4, 'G'),
#  (Decimal('41.90'), 'Senegal', 3, 'R'),
#  (Decimal('21.96'), 'Senegal', 4, 'R'),
#  (Decimal('5.98'), 'Senegal', 2, 'PG-13'),
#  (Decimal('13.96'), 'Senegal', 3, 'PG-13'),
#  (Decimal('17.94'), 'Senegal', 4, 'PG-13'),
#  (Decimal('15.96'), 'Senegal', 2, 'PG'),
#  (Decimal('9.96'), 'Senegal', 4, 'PG'),
#  (Decimal('9.98'), 'Senegal', 1, 'NC-17'),
#  (Decimal('23.94'), 'Senegal', 2, 'NC-17'),
#  (Decimal('27.96'), 'Senegal', 3, 'NC-17'),
#  (Decimal('5.98'), 'Senegal', 2, 'G'),
#  (Decimal('5.98'), 'Senegal', 3, 'G'),
#  (Decimal('19.96'), 'Saudi Arabia', 1, 'R'),
#  (Decimal('1.98'), 'Saudi Arabia', 2, 'R'),
#  (Decimal('61.82'), 'Saudi Arabia', 3, 'R'),
#  (Decimal('75.86'), 'Saudi Arabia', 4, 'R'),
#  (Decimal('1.98'), 'Saudi Arabia', 5, 'R'),
#  (Decimal('43.92'), 'Saudi Arabia', 1, 'PG-13'),
#  (Decimal('31.94'), 'Saudi Arabia', 2, 'PG-13'),
#  (Decimal('83.86'), 'Saudi Arabia', 3, 'PG-13'),
#  (Decimal('109.80'), 'Saudi Arabia', 4, 'PG-13'),
#  (Decimal('25.94'), 'Saudi Arabia', 1, 'PG'),
#  (Decimal('21.96'), 'Saudi Arabia', 2, 'PG'),
#  (Decimal('83.80'), 'Saudi Arabia', 3, 'PG'),
#  (Decimal('121.70'), 'Saudi Arabia', 4, 'PG'),
#  (Decimal('5.98'), 'Saudi Arabia', 5, 'PG'),
#  (Decimal('19.96'), 'Saudi Arabia', 1, 'NC-17'),
#  (Decimal('11.96'), 'Saudi Arabia', 2, 'NC-17'),
#  (Decimal('97.72'), 'Saudi Arabia', 3, 'NC-17'),
#  (Decimal('95.82'), 'Saudi Arabia', 4, 'NC-17'),
#  (Decimal('21.96'), 'Saudi Arabia', 1, 'G'),
#  (Decimal('7.98'), 'Saudi Arabia', 2, 'G'),
#  (Decimal('31.88'), 'Saudi Arabia', 3, 'G'),
#  (Decimal('69.80'), 'Saudi Arabia', 4, 'G'),
#  (Decimal('9.98'), 'Saint Vincent and the Grenadines', 1, 'R'),
#  (Decimal('1.98'), 'Saint Vincent and the Grenadines', 2, 'R'),
#  (Decimal('9.98'), 'Saint Vincent and the Grenadines', 3, 'R'),
#  (Decimal('21.96'), 'Saint Vincent and the Grenadines', 4, 'R'),
#  (Decimal('7.96'), 'Saint Vincent and the Grenadines', 3, 'PG-13'),
#  (Decimal('21.96'), 'Saint Vincent and the Grenadines', 4, 'PG-13'),
#  (Decimal('9.98'), 'Saint Vincent and the Grenadines', 3, 'PG'),
#  (Decimal('15.92'), 'Saint Vincent and the Grenadines', 4, 'PG'),
#  (Decimal('19.96'), 'Saint Vincent and the Grenadines', 2, 'NC-17'),
#  (Decimal('7.96'), 'Saint Vincent and the Grenadines', 3, 'NC-17'),
#  (Decimal('11.98'), 'Saint Vincent and the Grenadines', 4, 'NC-17'),
#  (Decimal('21.96'), 'Saint Vincent and the Grenadines', 1, 'G'),
#  (Decimal('9.98'), 'Saint Vincent and the Grenadines', 2, 'G'),
#  (Decimal('21.94'), 'Saint Vincent and the Grenadines', 4, 'G'),
#  (Decimal('71.80'), 'Russian Federation', 1, 'R'),
#  (Decimal('141.68'), 'Russian Federation', 2, 'R'),
#  (Decimal('454.94'), 'Russian Federation', 3, 'R'),
#  (Decimal('602.74'), 'Russian Federation', 4, 'R'),
#  (Decimal('11.96'), 'Russian Federation', 5, 'R'),
#  (Decimal('141.68'), 'Russian Federation', 1, 'PG-13'),
#  (Decimal('197.52'), 'Russian Federation', 2, 'PG-13'),
#  (Decimal('325.08'), 'Russian Federation', 3, 'PG-13'),
#  (Decimal('706.50'), 'Russian Federation', 4, 'PG-13'),
#  (Decimal('63.80'), 'Russian Federation', 1, 'PG'),
#  (Decimal('183.58'), 'Russian Federation', 2, 'PG'),
#  (Decimal('379.06'), 'Russian Federation', 3, 'PG'),
#  (Decimal('412.96'), 'Russian Federation', 4, 'PG'),
#  (Decimal('1.98'), 'Russian Federation', 5, 'PG'),
#  (Decimal('97.72'), 'Russian Federation', 1, 'NC-17'),
#  (Decimal('221.42'), 'Russian Federation', 2, 'NC-17'),
#  (Decimal('442.98'), 'Russian Federation', 3, 'NC-17'),
#  (Decimal('556.82'), 'Russian Federation', 4, 'NC-17'),
#  (Decimal('1.98'), 'Russian Federation', 5, 'NC-17'),
#  (Decimal('75.80'), 'Russian Federation', 1, 'G'),
#  (Decimal('107.68'), 'Russian Federation', 2, 'G'),
#  (Decimal('317.30'), 'Russian Federation', 3, 'G'),
#  (Decimal('574.76'), 'Russian Federation', 4, 'G'),
#  (Decimal('41.90'), 'Runion', 3, 'R'),
#  (Decimal('63.86'), 'Runion', 4, 'R'),
#  (Decimal('9.98'), 'Runion', 1, 'PG-13'),
#  (Decimal('21.96'), 'Runion', 2, 'PG-13'),
#  (Decimal('37.94'), 'Runion', 3, 'PG-13'),
#  (Decimal('43.92'), 'Runion', 4, 'PG-13'),
#  (Decimal('11.98'), 'Runion', 2, 'PG'),
#  (Decimal('29.94'), 'Runion', 3, 'PG'),
#  (Decimal('63.86'), 'Runion', 4, 'PG'),
#  (Decimal('7.98'), 'Runion', 2, 'NC-17'),
#  (Decimal('15.96'), 'Runion', 3, 'NC-17'),
#  (Decimal('11.96'), 'Runion', 4, 'NC-17'),
#  (Decimal('3.98'), 'Runion', 2, 'G'),
#  (Decimal('49.90'), 'Runion', 3, 'G'),
#  (Decimal('17.96'), 'Runion', 4, 'G'),
#  (Decimal('11.98'), 'Romania', 1, 'R'),
#  (Decimal('11.96'), 'Romania', 3, 'R'),
#  (Decimal('29.88'), 'Romania', 4, 'R'),
#  (Decimal('1.98'), 'Romania', 1, 'PG-13'),
#  (Decimal('9.98'), 'Romania', 2, 'PG-13'),
#  (Decimal('23.96'), 'Romania', 3, 'PG-13'),
#  (Decimal('47.88'), 'Romania', 4, 'PG-13'),
#  (Decimal('9.98'), 'Romania', 1, 'PG'),
#  (Decimal('31.90'), 'Romania', 3, 'PG'),
#  (Decimal('35.90'), 'Romania', 4, 'PG'),
#  (Decimal('21.94'), 'Romania', 2, 'NC-17'),
#  (Decimal('27.94'), 'Romania', 3, 'NC-17'),
#  (Decimal('47.86'), 'Romania', 4, 'NC-17'),
#  (Decimal('9.98'), 'Romania', 1, 'G'),
#  (Decimal('21.92'), 'Romania', 2, 'G'),
#  (Decimal('47.86'), 'Romania', 3, 'G'),
#  (Decimal('77.86'), 'Romania', 4, 'G'),
#  (Decimal('13.96'), 'Puerto Rico', 2, 'R'),
#  (Decimal('55.90'), 'Puerto Rico', 3, 'R'),
#  (Decimal('53.86'), 'Puerto Rico', 4, 'R'),
#  (Decimal('1.98'), 'Puerto Rico', 1, 'PG-13'),
#  (Decimal('13.98'), 'Puerto Rico', 2, 'PG-13'),
#  (Decimal('31.94'), 'Puerto Rico', 3, 'PG-13'),
#  (Decimal('13.94'), 'Puerto Rico', 4, 'PG-13'),
#  (Decimal('23.96'), 'Puerto Rico', 1, 'PG'),
#  (Decimal('11.96'), 'Puerto Rico', 2, 'PG'),
#  (Decimal('17.94'), 'Puerto Rico', 3, 'PG'),
#  (Decimal('95.86'), 'Puerto Rico', 4, 'PG'),
#  (Decimal('13.98'), 'Puerto Rico', 2, 'NC-17'),
#  (Decimal('5.98'), 'Puerto Rico', 3, 'NC-17'),
#  (Decimal('71.80'), 'Puerto Rico', 4, 'NC-17'),
#  (Decimal('1.98'), 'Puerto Rico', 5, 'NC-17'),
#  (Decimal('5.96'), 'Puerto Rico', 1, 'G'),
#  (Decimal('11.96'), 'Puerto Rico', 2, 'G'),
#  (Decimal('27.94'), 'Puerto Rico', 3, 'G'),
#  (Decimal('33.90'), 'Puerto Rico', 4, 'G'),
#  (Decimal('3.98'), 'Poland', 1, 'R'),
#  (Decimal('29.92'), 'Poland', 2, 'R'),
#  (Decimal('113.70'), 'Poland', 3, 'R'),
#  (Decimal('169.56'), 'Poland', 4, 'R'),
#  (Decimal('5.98'), 'Poland', 1, 'PG-13'),
#  (Decimal('109.78'), 'Poland', 2, 'PG-13'),
#  (Decimal('103.78'), 'Poland', 3, 'PG-13'),
#  (Decimal('149.66'), 'Poland', 4, 'PG-13'),
#  (Decimal('41.90'), 'Poland', 2, 'PG'),
#  (Decimal('131.66'), 'Poland', 3, 'PG'),
#  (Decimal('177.58'), 'Poland', 4, 'PG'),
#  (Decimal('63.92'), 'Poland', 1, 'NC-17'),
#  (Decimal('59.86'), 'Poland', 2, 'NC-17'),
#  (Decimal('115.64'), 'Poland', 3, 'NC-17'),
#  (Decimal('177.68'), 'Poland', 4, 'NC-17'),
#  (Decimal('35.90'), 'Poland', 1, 'G'),
#  (Decimal('81.86'), 'Poland', 2, 'G'),
#  (Decimal('79.82'), 'Poland', 3, 'G'),
#  (Decimal('103.76'), 'Poland', 4, 'G'),
#  (Decimal('97.80'), 'Philippines', 1, 'R'),
#  (Decimal('75.80'), 'Philippines', 2, 'R'),
#  (Decimal('275.44'), 'Philippines', 3, 'R'),
#  (Decimal('357.14'), 'Philippines', 4, 'R'),
#  (Decimal('5.98'), 'Philippines', 5, 'R'),
#  (Decimal('53.88'), 'Philippines', 1, 'PG-13'),
#  (Decimal('189.62'), 'Philippines', 2, 'PG-13'),
#  (Decimal('405.02'), 'Philippines', 3, 'PG-13'),
#  (Decimal('452.88'), 'Philippines', 4, 'PG-13'),
#  (Decimal('15.96'), 'Philippines', 5, 'PG-13'),
#  (Decimal('59.82'), 'Philippines', 1, 'PG'),
#  (Decimal('167.64'), 'Philippines', 2, 'PG'),
#  (Decimal('345.16'), 'Philippines', 3, 'PG'),
#  (Decimal('383.08'), 'Philippines', 4, 'PG'),
#  (Decimal('9.98'), 'Philippines', 5, 'PG'),
#  (Decimal('69.84'), 'Philippines', 1, 'NC-17'),
#  (Decimal('231.40'), 'Philippines', 2, 'NC-17'),
#  (Decimal('439.04'), 'Philippines', 3, 'NC-17'),
#  (Decimal('327.12'), 'Philippines', 4, 'NC-17'),
#  (Decimal('9.90'), 'Philippines', 5, 'NC-17'),
#  (Decimal('41.90'), 'Philippines', 1, 'G'),
#  (Decimal('53.88'), 'Philippines', 2, 'G'),
#  (Decimal('347.30'), 'Philippines', 3, 'G'),
#  (Decimal('337.08'), 'Philippines', 4, 'G'),
#  (Decimal('9.98'), 'Philippines', 5, 'G'),
#  (Decimal('41.94'), 'Peru', 1, 'R'),
#  (Decimal('43.92'), 'Peru', 2, 'R'),
#  (Decimal('69.84'), 'Peru', 3, 'R'),
#  (Decimal('105.74'), 'Peru', 4, 'R'),
#  (Decimal('19.92'), 'Peru', 1, 'PG-13'),
#  (Decimal('1.98'), 'Peru', 2, 'PG-13'),
#  (Decimal('61.86'), 'Peru', 3, 'PG-13'),
#  (Decimal('87.80'), 'Peru', 4, 'PG-13'),
#  (Decimal('17.98'), 'Peru', 1, 'PG'),
#  (Decimal('45.88'), 'Peru', 2, 'PG'),
#  (Decimal('115.74'), 'Peru', 3, 'PG'),
#  (Decimal('37.84'), 'Peru', 4, 'PG'),
#  (Decimal('1.98'), 'Peru', 1, 'NC-17'),
#  (Decimal('37.92'), 'Peru', 2, 'NC-17'),
#  (Decimal('77.80'), 'Peru', 3, 'NC-17'),
#  (Decimal('79.82'), 'Peru', 4, 'NC-17'),
#  (Decimal('13.96'), 'Peru', 2, 'G'),
#  (Decimal('21.98'), 'Peru', 3, 'G'),
#  (Decimal('43.88'), 'Peru', 4, 'G'),
#  (Decimal('9.98'), 'Peru', 5, 'G'),
#  (Decimal('31.94'), 'Paraguay', 2, 'R'),
#  (Decimal('47.92'), 'Paraguay', 3, 'R'),
#  (Decimal('51.88'), 'Paraguay', 4, 'R'),
#  (Decimal('9.98'), 'Paraguay', 2, 'PG-13'),
#  (Decimal('49.86'), 'Paraguay', 3, 'PG-13'),
#  (Decimal('61.88'), 'Paraguay', 4, 'PG-13'),
#  (Decimal('1.98'), 'Paraguay', 1, 'PG'),
#  (Decimal('13.94'), 'Paraguay', 2, 'PG'),
#  (Decimal('41.90'), 'Paraguay', 3, 'PG'),
#  (Decimal('9.98'), 'Paraguay', 4, 'PG'),
#  (Decimal('1.98'), 'Paraguay', 2, 'NC-17'),
#  (Decimal('17.94'), 'Paraguay', 3, 'NC-17'),
#  (Decimal('91.84'), 'Paraguay', 4, 'NC-17'),
#  (Decimal('1.98'), 'Paraguay', 1, 'G'),
#  (Decimal('11.96'), 'Paraguay', 2, 'G'),
#  (Decimal('25.94'), 'Paraguay', 3, 'G'),
#  (Decimal('77.86'), 'Paraguay', 4, 'G'),
#  (Decimal('45.92'), 'Pakistan', 2, 'R'),
#  (Decimal('53.86'), 'Pakistan', 3, 'R'),
#  (Decimal('51.90'), 'Pakistan', 4, 'R'),
#  (Decimal('31.92'), 'Pakistan', 1, 'PG-13'),
#  (Decimal('39.88'), 'Pakistan', 2, 'PG-13'),
#  (Decimal('41.88'), 'Pakistan', 3, 'PG-13'),
#  (Decimal('85.76'), 'Pakistan', 4, 'PG-13'),
#  (Decimal('41.92'), 'Pakistan', 2, 'PG'),
#  (Decimal('79.78'), 'Pakistan', 3, 'PG'),
#  (Decimal('129.72'), 'Pakistan', 4, 'PG'),
#  (Decimal('15.96'), 'Pakistan', 1, 'NC-17'),
#  (Decimal('21.94'), 'Pakistan', 2, 'NC-17'),
#  (Decimal('105.76'), 'Pakistan', 3, 'NC-17'),
#  (Decimal('65.80'), 'Pakistan', 4, 'NC-17'),
#  (Decimal('55.88'), 'Pakistan', 1, 'G'),
#  (Decimal('13.96'), 'Pakistan', 2, 'G'),
#  (Decimal('135.72'), 'Pakistan', 3, 'G'),
#  (Decimal('33.88'), 'Pakistan', 4, 'G'),
#  (Decimal('29.94'), 'Oman', 1, 'R'),
#  (Decimal('37.92'), 'Oman', 2, 'R'),
#  (Decimal('1.98'), 'Oman', 3, 'R'),
#  (Decimal('39.88'), 'Oman', 4, 'R'),
#  (Decimal('19.96'), 'Oman', 2, 'PG-13'),
#  (Decimal('35.92'), 'Oman', 3, 'PG-13'),
#  (Decimal('9.94'), 'Oman', 4, 'PG-13'),
#  (Decimal('9.98'), 'Oman', 5, 'PG-13'),
#  (Decimal('1.98'), 'Oman', 3, 'PG'),
#  (Decimal('11.96'), 'Oman', 4, 'PG'),
#  (Decimal('5.98'), 'Oman', 1, 'NC-17'),
#  (Decimal('7.96'), 'Oman', 2, 'NC-17'),
#  (Decimal('33.94'), 'Oman', 3, 'NC-17'),
#  (Decimal('29.92'), 'Oman', 4, 'NC-17'),
#  (Decimal('15.96'), 'Oman', 1, 'G'),
#  (Decimal('11.96'), 'Oman', 3, 'G'),
#  (Decimal('69.82'), 'Oman', 4, 'G'),
#  (Decimal('1.98'), 'North Korea', 2, 'R'),
#  (Decimal('25.96'), 'North Korea', 3, 'R'),
#  (Decimal('13.94'), 'North Korea', 4, 'R'),
#  (Decimal('1.98'), 'North Korea', 1, 'PG-13'),
#  (Decimal('15.96'), 'North Korea', 3, 'PG-13'),
#  (Decimal('35.90'), 'North Korea', 4, 'PG-13'),
#  (Decimal('9.98'), 'North Korea', 3, 'PG'),
#  (Decimal('3.96'), 'North Korea', 4, 'PG'),
#  (Decimal('9.98'), 'North Korea', 1, 'NC-17'),
#  (Decimal('35.92'), 'North Korea', 3, 'NC-17'),
#  (Decimal('41.90'), 'North Korea', 4, 'NC-17'),
#  (Decimal('9.98'), 'North Korea', 3, 'G'),
#  (Decimal('19.94'), 'North Korea', 4, 'G'),
#  (Decimal('35.96'), 'Nigeria', 1, 'R'),
#  (Decimal('87.78'), 'Nigeria', 2, 'R'),
#  (Decimal('203.52'), 'Nigeria', 3, 'R'),
#  (Decimal('203.40'), 'Nigeria', 4, 'R'),
#  (Decimal('0.00'), 'Nigeria', 5, 'R'),
#  (Decimal('65.86'), 'Nigeria', 1, 'PG-13'),
#  (Decimal('57.86'), 'Nigeria', 2, 'PG-13'),
#  (Decimal('197.54'), 'Nigeria', 3, 'PG-13'),
#  (Decimal('283.28'), 'Nigeria', 4, 'PG-13'),
#  (Decimal('5.98'), 'Nigeria', 5, 'PG-13'),
#  (Decimal('59.84'), 'Nigeria', 1, 'PG'),
#  (Decimal('71.84'), 'Nigeria', 2, 'PG'),
#  (Decimal('269.40'), 'Nigeria', 3, 'PG'),
#  (Decimal('395.16'), 'Nigeria', 4, 'PG'),
#  (Decimal('61.88'), 'Nigeria', 1, 'NC-17'),
#  (Decimal('75.84'), 'Nigeria', 2, 'NC-17'),
#  (Decimal('229.46'), 'Nigeria', 3, 'NC-17'),
#  (Decimal('207.48'), 'Nigeria', 4, 'NC-17'),
#  (Decimal('11.96'), 'Nigeria', 5, 'NC-17'),
#  (Decimal('45.88'), 'Nigeria', 1, 'G'),
#  (Decimal('61.88'), 'Nigeria', 2, 'G'),
#  (Decimal('185.62'), 'Nigeria', 3, 'G'),
#  (Decimal('205.54'), 'Nigeria', 4, 'G'),
#  (Decimal('11.98'), 'New Zealand', 2, 'R'),
#  (Decimal('15.98'), 'New Zealand', 3, 'R'),
#  (Decimal('7.98'), 'New Zealand', 4, 'R'),
#  (Decimal('5.98'), 'New Zealand', 3, 'PG-13'),
#  (Decimal('23.94'), 'New Zealand', 4, 'PG-13'),
#  (Decimal('13.98'), 'New Zealand', 1, 'PG'),
#  (Decimal('5.98'), 'New Zealand', 2, 'PG'),
#  (Decimal('21.94'), 'New Zealand', 3, 'PG'),
#  (Decimal('1.98'), 'New Zealand', 4, 'PG'),
#  (Decimal('9.98'), 'New Zealand', 2, 'NC-17'),
#  (Decimal('7.96'), 'New Zealand', 3, 'NC-17'),
#  (Decimal('11.94'), 'New Zealand', 4, 'NC-17'),
#  (Decimal('19.98'), 'New Zealand', 3, 'G'),
#  (Decimal('25.92'), 'New Zealand', 4, 'G'),
#  (Decimal('13.96'), 'Netherlands', 1, 'R'),
#  (Decimal('45.94'), 'Netherlands', 2, 'R'),
#  (Decimal('125.66'), 'Netherlands', 3, 'R'),
#  (Decimal('89.74'), 'Netherlands', 4, 'R'),
#  (Decimal('63.88'), 'Netherlands', 2, 'PG-13'),
#  (Decimal('103.80'), 'Netherlands', 3, 'PG-13'),
#  (Decimal('135.78'), 'Netherlands', 4, 'PG-13'),
#  (Decimal('39.90'), 'Netherlands', 2, 'PG'),
#  (Decimal('113.74'), 'Netherlands', 3, 'PG'),
#  (Decimal('119.74'), 'Netherlands', 4, 'PG'),
#  (Decimal('37.92'), 'Netherlands', 1, 'NC-17'),
#  (Decimal('5.98'), 'Netherlands', 2, 'NC-17'),
#  (Decimal('77.84'), 'Netherlands', 3, 'NC-17'),
#  (Decimal('83.76'), 'Netherlands', 4, 'NC-17'),
#  (Decimal('1.98'), 'Netherlands', 5, 'NC-17'),
#  (Decimal('17.96'), 'Netherlands', 2, 'G'),
#  (Decimal('51.88'), 'Netherlands', 3, 'G'),
#  (Decimal('43.86'), 'Netherlands', 4, 'G'),
#  (Decimal('9.98'), 'Nepal', 1, 'R'),
#  (Decimal('11.98'), 'Nepal', 2, 'R'),
#  (Decimal('43.92'), 'Nepal', 3, 'R'),
#  (Decimal('27.96'), 'Nepal', 4, 'R'),
#  (Decimal('11.98'), 'Nepal', 1, 'PG-13'),
#  (Decimal('1.98'), 'Nepal', 2, 'PG-13'),
#  (Decimal('11.98'), 'Nepal', 3, 'PG-13'),
#  (Decimal('25.92'), 'Nepal', 4, 'PG-13'),
#  (Decimal('9.98'), 'Nepal', 1, 'PG'),
#  (Decimal('13.98'), 'Nepal', 3, 'PG'),
#  (Decimal('33.94'), 'Nepal', 4, 'PG'),
#  (Decimal('13.98'), 'Nepal', 4, 'NC-17'),
#  (Decimal('15.98'), 'Nepal', 3, 'G'),
#  (Decimal('5.98'), 'Nauru', 2, 'R'),
#  (Decimal('59.88'), 'Nauru', 3, 'R'),
#  (Decimal('19.98'), 'Nauru', 4, 'R'),
#  (Decimal('15.96'), 'Nauru', 3, 'PG-13'),
#  (Decimal('21.96'), 'Nauru', 4, 'PG-13'),
#  (Decimal('3.98'), 'Nauru', 2, 'PG'),
#  (Decimal('27.94'), 'Nauru', 3, 'PG'),
#  (Decimal('25.94'), 'Nauru', 4, 'PG'),
#  (Decimal('9.98'), 'Nauru', 1, 'NC-17'),
#  (Decimal('27.96'), 'Nauru', 3, 'NC-17'),
#  (Decimal('41.90'), 'Nauru', 4, 'NC-17'),
#  (Decimal('15.98'), 'Nauru', 2, 'G'),
#  (Decimal('7.98'), 'Nauru', 3, 'G'),
#  (Decimal('11.96'), 'Nauru', 4, 'G'),
#  (Decimal('9.98'), 'Myanmar', 2, 'R'),
#  (Decimal('37.92'), 'Myanmar', 3, 'R'),
#  (Decimal('17.96'), 'Myanmar', 4, 'R'),
#  (Decimal('11.96'), 'Myanmar', 1, 'PG-13'),
#  (Decimal('23.94'), 'Myanmar', 2, 'PG-13'),
#  (Decimal('35.92'), 'Myanmar', 3, 'PG-13'),
#  (Decimal('13.96'), 'Myanmar', 4, 'PG-13'),
#  (Decimal('23.92'), 'Myanmar', 2, 'PG'),
#  (Decimal('67.90'), 'Myanmar', 3, 'PG'),
#  (Decimal('7.96'), 'Myanmar', 4, 'PG'),
#  (Decimal('17.94'), 'Myanmar', 1, 'NC-17'),
#  (Decimal('1.98'), 'Myanmar', 2, 'NC-17'),
#  (Decimal('27.90'), 'Myanmar', 3, 'NC-17'),
#  (Decimal('11.94'), 'Myanmar', 4, 'NC-17'),
#  (Decimal('35.92'), 'Myanmar', 2, 'G'),
#  (Decimal('23.90'), 'Myanmar', 3, 'G'),
#  (Decimal('17.96'), 'Myanmar', 4, 'G'),
#  (Decimal('83.82'), 'Mozambique', 3, 'R'),
#  (Decimal('101.80'), 'Mozambique', 4, 'R'),
#  (Decimal('9.98'), 'Mozambique', 2, 'PG-13'),
#  (Decimal('35.92'), 'Mozambique', 3, 'PG-13'),
#  (Decimal('89.80'), 'Mozambique', 4, 'PG-13'),
#  (Decimal('27.96'), 'Mozambique', 1, 'PG'),
#  (Decimal('9.98'), 'Mozambique', 2, 'PG'),
#  (Decimal('17.94'), 'Mozambique', 3, 'PG'),
#  (Decimal('61.84'), 'Mozambique', 4, 'PG'),
#  (Decimal('11.96'), 'Mozambique', 1, 'NC-17'),
#  (Decimal('3.96'), 'Mozambique', 2, 'NC-17'),
#  (Decimal('47.88'), 'Mozambique', 3, 'NC-17'),
#  (Decimal('61.84'), 'Mozambique', 4, 'NC-17'),
#  (Decimal('17.98'), 'Mozambique', 1, 'G'),
#  (Decimal('5.98'), 'Mozambique', 2, 'G'),
#  (Decimal('23.92'), 'Mozambique', 3, 'G'),
#  (Decimal('75.84'), 'Mozambique', 4, 'G'),
#  (Decimal('13.96'), 'Morocco', 1, 'R'),
#  (Decimal('19.94'), 'Morocco', 2, 'R'),
#  (Decimal('85.78'), 'Morocco', 3, 'R'),
#  (Decimal('61.86'), 'Morocco', 4, 'R'),
#  (Decimal('9.98'), 'Morocco', 5, 'R'),
#  (Decimal('9.98'), 'Morocco', 1, 'PG-13'),
#  (Decimal('5.98'), 'Morocco', 2, 'PG-13'),
#  (Decimal('45.92'), 'Morocco', 3, 'PG-13'),
#  (Decimal('69.82'), 'Morocco', 4, 'PG-13'),
#  (Decimal('5.98'), 'Morocco', 2, 'PG'),
#  (Decimal('51.88'), 'Morocco', 3, 'PG'),
#  (Decimal('19.94'), 'Morocco', 4, 'PG'),
#  (Decimal('23.96'), 'Morocco', 1, 'NC-17'),
#  (Decimal('51.90'), 'Morocco', 2, 'NC-17'),
#  (Decimal('31.94'), 'Morocco', 3, 'NC-17'),
#  (Decimal('11.96'), 'Morocco', 4, 'NC-17'),
#  (Decimal('17.98'), 'Morocco', 1, 'G'),
#  (Decimal('37.92'), 'Morocco', 3, 'G'),
#  (Decimal('37.90'), 'Morocco', 4, 'G'),
#  (Decimal('3.98'), 'Moldova', 2, 'R'),
#  (Decimal('13.98'), 'Moldova', 3, 'R'),
#  (Decimal('45.88'), 'Moldova', 4, 'R'),
#  (Decimal('13.96'), 'Moldova', 2, 'PG-13'),
#  (Decimal('47.88'), 'Moldova', 3, 'PG-13'),
#  (Decimal('33.92'), 'Moldova', 4, 'PG-13'),
#  (Decimal('9.98'), 'Moldova', 3, 'PG'),
#  (Decimal('17.94'), 'Moldova', 4, 'PG'),
#  (Decimal('13.96'), 'Moldova', 2, 'NC-17'),
#  (Decimal('19.94'), 'Moldova', 3, 'NC-17'),
#  (Decimal('27.92'), 'Moldova', 4, 'NC-17'),
#  (Decimal('5.98'), 'Moldova', 4, 'G'),
#  (Decimal('111.68'), 'Mexico', 1, 'R'),
#  (Decimal('241.54'), 'Mexico', 2, 'R'),
#  (Decimal('498.88'), 'Mexico', 3, 'R'),
#  (Decimal('532.78'), 'Mexico', 4, 'R'),
#  (Decimal('15.96'), 'Mexico', 5, 'R'),
#  (Decimal('91.78'), 'Mexico', 1, 'PG-13'),
#  (Decimal('159.50'), 'Mexico', 2, 'PG-13'),
#  (Decimal('478.76'), 'Mexico', 3, 'PG-13'),
#  (Decimal('718.34'), 'Mexico', 4, 'PG-13'),
#  (Decimal('163.66'), 'Mexico', 1, 'PG'),
#  (Decimal('159.58'), 'Mexico', 2, 'PG'),
#  (Decimal('434.92'), 'Mexico', 3, 'PG'),
#  (Decimal('492.78'), 'Mexico', 4, 'PG'),
#  (Decimal('1.98'), 'Mexico', 5, 'PG'),
#  (Decimal('85.84'), 'Mexico', 1, 'NC-17'),
#  (Decimal('287.42'), 'Mexico', 2, 'NC-17'),
#  (Decimal('478.78'), 'Mexico', 3, 'NC-17'),
#  (Decimal('480.94'), 'Mexico', 4, 'NC-17'),
#  (Decimal('7.96'), 'Mexico', 5, 'NC-17'),
#  (Decimal('73.78'), 'Mexico', 1, 'G'),
#  (Decimal('161.62'), 'Mexico', 2, 'G'),
#  (Decimal('384.88'), 'Mexico', 3, 'G'),
#  (Decimal('548.74'), 'Mexico', 4, 'G'),
#  (Decimal('1.98'), 'Mexico', 5, 'G'),
#  (Decimal('9.96'), 'Malaysia', 1, 'R'),
#  (Decimal('33.92'), 'Malaysia', 2, 'R'),
#  (Decimal('45.88'), 'Malaysia', 3, 'R'),
#  (Decimal('35.90'), 'Malaysia', 4, 'R'),
#  (Decimal('19.96'), 'Malaysia', 2, 'PG-13'),
#  (Decimal('21.96'), 'Malaysia', 3, 'PG-13'),
#  (Decimal('63.82'), 'Malaysia', 4, 'PG-13'),
#  (Decimal('1.98'), 'Malaysia', 5, 'PG-13'),
#  (Decimal('23.94'), 'Malaysia', 2, 'PG'),
#  (Decimal('113.76'), 'Malaysia', 3, 'PG'),
#  (Decimal('59.84'), 'Malaysia', 4, 'PG'),
#  (Decimal('15.96'), 'Malaysia', 1, 'NC-17'),
#  (Decimal('15.96'), 'Malaysia', 2, 'NC-17'),
#  (Decimal('21.96'), 'Malaysia', 3, 'NC-17'),
#  (Decimal('77.84'), 'Malaysia', 4, 'NC-17'),
#  (Decimal('35.96'), 'Malaysia', 1, 'G'),
#  (Decimal('1.98'), 'Malaysia', 2, 'G'),
#  (Decimal('107.78'), 'Malaysia', 3, 'G'),
#  (Decimal('29.94'), 'Malaysia', 4, 'G'),
#  (Decimal('7.98'), 'Malawi', 2, 'R'),
#  (Decimal('33.94'), 'Malawi', 3, 'R'),
#  (Decimal('13.98'), 'Malawi', 4, 'R'),
#  (Decimal('5.98'), 'Malawi', 2, 'PG-13'),
#  (Decimal('25.96'), 'Malawi', 3, 'PG-13'),
#  (Decimal('23.96'), 'Malawi', 4, 'PG-13'),
#  (Decimal('11.98'), 'Malawi', 2, 'PG'),
#  (Decimal('3.98'), 'Malawi', 3, 'PG'),
#  (Decimal('35.90'), 'Malawi', 4, 'PG'),
#  (Decimal('21.96'), 'Malawi', 3, 'NC-17'),
#  (Decimal('15.96'), 'Malawi', 4, 'NC-17'),
#  (Decimal('3.98'), 'Malawi', 1, 'G'),
#  (Decimal('1.98'), 'Malawi', 2, 'G'),
#  (Decimal('15.96'), 'Malawi', 3, 'G'),
#  (Decimal('23.94'), 'Malawi', 4, 'G'),
#  (Decimal('35.92'), 'Madagascar', 3, 'R'),
#  (Decimal('1.98'), 'Madagascar', 1, 'PG-13'),
#  (Decimal('9.98'), 'Madagascar', 2, 'PG-13'),
#  (Decimal('11.98'), 'Madagascar', 3, 'PG-13'),
#  (Decimal('25.96'), 'Madagascar', 3, 'PG'),
#  (Decimal('19.94'), 'Madagascar', 4, 'PG'),
#  (Decimal('15.96'), 'Madagascar', 2, 'NC-17'),
#  (Decimal('27.92'), 'Madagascar', 3, 'NC-17'),
#  (Decimal('19.98'), 'Madagascar', 4, 'NC-17'),
#  (Decimal('9.98'), 'Madagascar', 3, 'G'),
#  (Decimal('7.96'), 'Madagascar', 4, 'G'),
#  (Decimal('7.96'), 'Lithuania', 3, 'R'),
#  (Decimal('9.96'), 'Lithuania', 4, 'R'),
#  (Decimal('13.98'), 'Lithuania', 2, 'PG-13'),
#  (Decimal('11.96'), 'Lithuania', 3, 'PG-13'),
#  (Decimal('13.94'), 'Lithuania', 4, 'PG-13'),
#  (Decimal('9.98'), 'Lithuania', 1, 'PG'),
#  (Decimal('9.96'), 'Lithuania', 2, 'PG'),
#  (Decimal('1.98'), 'Lithuania', 3, 'PG'),
#  (Decimal('9.98'), 'Lithuania', 5, 'PG'),
#  (Decimal('9.98'), 'Lithuania', 1, 'NC-17'),
#  (Decimal('5.96'), 'Lithuania', 3, 'NC-17'),
#  (Decimal('19.96'), 'Lithuania', 4, 'NC-17'),
#  (Decimal('11.98'), 'Lithuania', 3, 'G'),
#  (Decimal('9.94'), 'Lithuania', 4, 'G'),
#  (Decimal('9.98'), 'Liechtenstein', 1, 'R'),
#  (Decimal('9.98'), 'Liechtenstein', 2, 'R'),
#  (Decimal('21.92'), 'Liechtenstein', 4, 'R'),
#  (Decimal('11.98'), 'Liechtenstein', 3, 'PG-13'),
#  (Decimal('31.94'), 'Liechtenstein', 4, 'PG-13'),
#  (Decimal('1.98'), 'Liechtenstein', 2, 'PG'),
#  (Decimal('1.98'), 'Liechtenstein', 3, 'PG'),
#  (Decimal('11.96'), 'Liechtenstein', 4, 'PG'),
#  (Decimal('15.98'), 'Liechtenstein', 2, 'NC-17'),
#  (Decimal('41.94'), 'Liechtenstein', 3, 'NC-17'),
#  (Decimal('25.94'), 'Liechtenstein', 4, 'NC-17'),
#  (Decimal('19.98'), 'Liechtenstein', 1, 'G'),
#  (Decimal('13.96'), 'Liechtenstein', 2, 'G'),
#  (Decimal('1.98'), 'Liechtenstein', 3, 'G'),
#  (Decimal('7.94'), 'Liechtenstein', 4, 'G'),
#  (Decimal('37.94'), 'Latvia', 2, 'R'),
#  (Decimal('41.94'), 'Latvia', 3, 'R'),
#  (Decimal('41.86'), 'Latvia', 4, 'R'),
#  (Decimal('5.98'), 'Latvia', 5, 'R'),
#  (Decimal('5.98'), 'Latvia', 1, 'PG-13'),
#  (Decimal('65.82'), 'Latvia', 3, 'PG-13'),
#  (Decimal('59.86'), 'Latvia', 4, 'PG-13'),
#  (Decimal('17.98'), 'Latvia', 1, 'PG'),
#  (Decimal('7.96'), 'Latvia', 2, 'PG'),
#  (Decimal('17.96'), 'Latvia', 3, 'PG'),
#  (Decimal('85.82'), 'Latvia', 4, 'PG'),
#  (Decimal('29.94'), 'Latvia', 2, 'NC-17'),
#  (Decimal('9.98'), 'Latvia', 3, 'NC-17'),
#  (Decimal('33.92'), 'Latvia', 4, 'NC-17'),
#  (Decimal('1.98'), 'Latvia', 1, 'G'),
#  (Decimal('21.96'), 'Latvia', 2, 'G'),
#  (Decimal('5.98'), 'Latvia', 3, 'G'),
#  (Decimal('31.94'), 'Latvia', 4, 'G'),
#  (Decimal('3.96'), 'Kuwait', 3, 'R'),
#  (Decimal('25.96'), 'Kuwait', 2, 'PG-13'),
#  (Decimal('7.98'), 'Kuwait', 3, 'PG-13'),
#  (Decimal('17.96'), 'Kuwait', 4, 'PG-13'),
#  (Decimal('17.96'), 'Kuwait', 2, 'PG'),
#  (Decimal('7.98'), 'Kuwait', 3, 'PG'),
#  (Decimal('11.98'), 'Kuwait', 4, 'PG'),
#  (Decimal('1.98'), 'Kuwait', 2, 'NC-17'),
#  (Decimal('49.90'), 'Kuwait', 3, 'NC-17'),
#  (Decimal('9.98'), 'Kuwait', 1, 'G'),
#  (Decimal('27.94'), 'Kuwait', 2, 'G'),
#  (Decimal('37.92'), 'Kuwait', 3, 'G'),
#  (Decimal('1.98'), 'Kuwait', 5, 'G'),
#  (Decimal('45.90'), 'Kenya', 2, 'R'),
#  (Decimal('37.92'), 'Kenya', 3, 'R'),
#  (Decimal('33.90'), 'Kenya', 4, 'R'),
#  ...]

# %% [markdown]
# #### Using 'CUBE' syntax
# The 'CUBE' syntax is the same as *including every possible combination in 'GROUPING SETS'*
# To review, the code below shows 3 different ways of grouping and what their results will be
# ```
# SELECT SUM(sales_amount) AS amount, c.country, d.month, m.rating
# FROM factsales
# JOIN dimmovie m ON factsales.movie_key = m.movie_key
# JOIN dimcustomer c ON factsales.customer_key = c.customer_key
# JOIN dimdate d ON factsales.date_key = d.date_key
# WHERE d.month = 5
#
# -- This will only calculate one single crosstab - the overlap between all attributes (overlaps between only 2 attributes, or no groupings at all are not shown)
# GROUP BY (c.country, d.month, m.rating)
#
# -- This allows you to calculate crosstabs BETWEEN ONLY SPECIFIC ATTRIBUTES
# GROUP BY GROUPING SETS ((), c.country, d.month,(c.country, m.rating));
#
# -- This calculates crosstabs between ALL POSSIBLE ATTRIBUTE COMBINATIONS
# GROUP BY CUBE(c.country, d.month, m.rating)
# ```

# %%
# %sql select DISTINCT d.month FROM dimdate d
# Out:
#  * postgresql://basic_user:***@127.0.0.1:5432/pagila
# 5 rows affected.
# [(3,), (5,), (4,), (2,), (1,)]
